# %% [markdown]
# # Проект MobileGame
# ## Задание 1

# %% [markdown]
# ### 1 Когортный анализ и расчет retention

# %%
# Импортируем библиотеки
import pandas as pd
import datetime as dt
import requests
from urllib.parse import urlencode

# %%
# Создаем функцию для загрузки данных с яндекс-диска
def yandex_read_csv(public_key):
    # используем api
    base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
    # получаем url
    final_url = base_url + urlencode(dict(public_key=public_key))
    response = requests.get(final_url)
    download_url = response.json()['href']
    # загружаем файл в df
    download_response = requests.get(download_url)
    df = pd.read_csv(download_url, sep=';')
    return df

# %%
# Загружаем данные
reg_data = yandex_read_csv('https://disk.yandex.ru/d/SRs6qGjPFc2GJg') # данные о времени регистрации
auth_data = yandex_read_csv('https://disk.yandex.ru/d/ytkERKye_ZFK5A') # данные о времени захода пользователей в игру

# %%
# Посмотрим как выглядят данные о времени регистрации
reg_data.head(2)
# Out:
#       reg_ts  uid
# 0  911382223    1
# 1  932683089    2

# %%
# Размер таблицы
print('Размер таблицы:', reg_data.shape)
# Типы данных
print ('Типы данных:\n', reg_data.dtypes)
# Out:
# Размер таблицы: (1000000, 2)
# Типы данных:
#  reg_ts    int64
# uid       int64
# dtype: object

# %%
# Посмотрим как выглядят данные о времени захода пользователей в игру
auth_data.head(2)
# Out:
#      auth_ts  uid
# 0  911382223    1
# 1  932683089    2

# %%
# Размер таблицы
print('Размер таблицы:', auth_data.shape)
# Типы данных
print ('Типы данных:\n', auth_data.dtypes)
# Out:
# Размер таблицы: (9601013, 2)
# Типы данных:
#  auth_ts    int64
# uid        int64
# dtype: object

# %% [markdown]
# Описание данных:
# - reg_ts - дата регистрации
# - uid - идентификатор игрока
# - auth_ts - дата захода пользователей в игру

# %% [markdown]
# Так как период для анализа слишком велик (более 20 лет), необходимо ограничить диапазон анализа. Ограничить необходимо как дату регистрации, так и дату захода пользователей в игру. Связано это с тем, что могут быть пользователи, которые играют длительный промежуток времени

# %%
# Посмотрим за какой период у нас сейчас есть данные
print('Дата первой регистрации:', dt.datetime.utcfromtimestamp(reg_data.reg_ts.min()).strftime('%Y-%m-%d'))
print('Дата последней регистрации:', dt.datetime.utcfromtimestamp(reg_data.reg_ts.max()).strftime('%Y-%m-%d'))
print('Дата первого захода пользователя в игру:', dt.datetime.utcfromtimestamp(auth_data.auth_ts.min()).strftime('%Y-%m-%d'))
print('Дата последнего захода пользователя в игру:', dt.datetime.utcfromtimestamp(auth_data.auth_ts.max()).strftime('%Y-%m-%d'))
# Out:
# Дата первой регистрации: 1998-11-18
# Дата последней регистрации: 2020-09-23
# Дата первого захода пользователя в игру: 1998-11-18
# Дата последнего захода пользователя в игру: 2020-09-23

# %%
# В качестве тестового расчета возьмем даты последнего месяца. 
date_start = '2020-09-01'
date_end = '2020-09-24'  # Прибавляем 1 день к последнему дню, так как при переводе в timestamp отсутствуют часы и минуты.
                         # Если указать 2020-09-23 то не будут учтены данные после 00:00.

# %%
# Переведем даты в формат timestamp, так как данные формата int будут обрабатываться быстрее, чем формата date 
date_start = dt.datetime.strptime(date_start, "%Y-%m-%d").timestamp()
date_end = dt.datetime.strptime(date_end, "%Y-%m-%d").timestamp()

# %% [markdown]
# Пользователь может начать играть только после регистрации. Оставим только данные, в которых время регистрации и время захода больше времени, с которого мы начинаем анализировать. Таким образом, мы уменьшим таблицы и ускорим процесс вычисления

# %%
reg_data = reg_data.query('reg_ts >= @date_start')
auth_data = auth_data.query('auth_ts >= @date_start')

# %%
# Объединяем данные по общему полю. 
cohort = reg_data.merge(auth_data, how='left', on='uid')

# %%
# Ограничим анализируемы период захода пользователей в игру
cohort = cohort.query('auth_ts <= @date_end')

# %%
# Изменим тип даты из timestamp в date (retention для примера расчитаем в днях)
cohort.reg_ts = cohort.reg_ts.apply(lambda x: dt.datetime.utcfromtimestamp(x).strftime('%Y-%m-%d'))
cohort.auth_ts = cohort.auth_ts.apply(lambda x: dt.datetime.utcfromtimestamp(x).strftime('%Y-%m-%d'))

# %%
# Посчитаем количество уникальных пользователей
cohort = cohort.groupby(['reg_ts', 'auth_ts'], as_index=False).agg({'uid': 'nunique'})

# %%
# Добавим в таблицу столбец с периодом (номерация от первого заказа до последующего)
cohort['period'] = cohort.sort_values(['reg_ts', 'auth_ts'], ascending=True).groupby(['reg_ts']).cumcount()

# %%
# Добавим в таблицу столбец retention
cohort['retention'] = cohort.uid / cohort.groupby('reg_ts')['uid'].transform('max')

# %%
# Приведем в читаемый вид
retention = cohort.pivot(index='reg_ts', columns='period', values='retention')

# %%
ur_style = (retention
            .style
            .set_caption('User retention by cohort')  # добавляем подпись
            .background_gradient(cmap='viridis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{:.2%}", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту
ur_style
# Out:
# <style type="text/css">
# #T_e19f7_row0_col0, #T_e19f7_row0_col7, #T_e19f7_row1_col0, #T_e19f7_row1_col22, #T_e19f7_row2_col0, #T_e19f7_row2_col21, #T_e19f7_row3_col0, #T_e19f7_row3_col20, #T_e19f7_row4_col0, #T_e19f7_row4_col19, #T_e19f7_row5_col0, #T_e19f7_row5_col18, #T_e19f7_row6_col0, #T_e19f7_row6_col17, #T_e19f7_row7_col0, #T_e19f7_row7_col16, #T_e19f7_row8_col0, #T_e19f7_row8_col15, #T_e19f7_row9_col0, #T_e19f7_row9_col14, #T_e19f7_row10_col0, #T_e19f7_row10_col13, #T_e19f7_row11_col0, #T_e19f7_row11_col12, #T_e19f7_row12_col0, #T_e19f7_row12_col11, #T_e19f7_row13_col0, #T_e19f7_row13_col10, #T_e19f7_row14_col0, #T_e19f7_row14_col9, #T_e19f7_row15_col0, #T_e19f7_row15_col8, #T_e19f7_row16_col0, #T_e19f7_row17_col0, #T_e19f7_row17_col6, #T_e19f7_row18_col0, #T_e19f7_row18_col5, #T_e19f7_row19_col0, #T_e19f7_row19_col4, #T_e19f7_row20_col0, #T_e19f7_row20_col3, #T_e19f7_row21_col0, #T_e19f7_row21_col2, #T_e19f7_row22_col0, #T_e19f7_row22_col1, #T_e19f7_row23_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col1, #T_e19f7_row0_col3, #T_e19f7_row0_col4, #T_e19f7_row0_col6, #T_e19f7_row0_col9, #T_e19f7_row0_col10, #T_e19f7_row0_col14, #T_e19f7_row0_col16, #T_e19f7_row0_col22, #T_e19f7_row1_col17, #T_e19f7_row1_col21, #T_e19f7_row2_col20, #T_e19f7_row3_col2, #T_e19f7_row3_col13, #T_e19f7_row3_col15, #T_e19f7_row3_col19, #T_e19f7_row4_col18, #T_e19f7_row6_col8, #T_e19f7_row7_col11, #T_e19f7_row8_col5, #T_e19f7_row8_col12, #T_e19f7_row10_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e19f7_row0_col2 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col5, #T_e19f7_row3_col4, #T_e19f7_row3_col6 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_e19f7_row0_col8, #T_e19f7_row3_col9 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_e19f7_row0_col11, #T_e19f7_row11_col9 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col12, #T_e19f7_row10_col1 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col13, #T_e19f7_row12_col9, #T_e19f7_row15_col6 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col15 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col17, #T_e19f7_row1_col12, #T_e19f7_row1_col15, #T_e19f7_row2_col10, #T_e19f7_row7_col7, #T_e19f7_row10_col10 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col18, #T_e19f7_row5_col1 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col19, #T_e19f7_row5_col16, #T_e19f7_row7_col8 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col20, #T_e19f7_row7_col4, #T_e19f7_row11_col5 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_e19f7_row0_col21, #T_e19f7_row7_col2, #T_e19f7_row11_col10, #T_e19f7_row16_col2 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col1 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col2 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col3, #T_e19f7_row11_col8 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col4 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col5, #T_e19f7_row5_col9, #T_e19f7_row5_col10, #T_e19f7_row6_col4 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col6, #T_e19f7_row2_col13 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col7, #T_e19f7_row4_col8 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_e19f7_row1_col8, #T_e19f7_row5_col12, #T_e19f7_row8_col3 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col9, #T_e19f7_row4_col5, #T_e19f7_row15_col7 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col10 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col11, #T_e19f7_row3_col8, #T_e19f7_row8_col7, #T_e19f7_row8_col11 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_e19f7_row1_col13, #T_e19f7_row6_col12, #T_e19f7_row9_col11 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_e19f7_row1_col14, #T_e19f7_row13_col2 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col16, #T_e19f7_row8_col4, #T_e19f7_row10_col9, #T_e19f7_row15_col2 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col18, #T_e19f7_row10_col12, #T_e19f7_row12_col3, #T_e19f7_row19_col3 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_e19f7_row1_col19, #T_e19f7_row12_col5 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_e19f7_row1_col20, #T_e19f7_row9_col13, #T_e19f7_row13_col7 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col1, #T_e19f7_row4_col3, #T_e19f7_row4_col12, #T_e19f7_row5_col2 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col2, #T_e19f7_row12_col4 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col3 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_e19f7_row2_col4, #T_e19f7_row5_col3, #T_e19f7_row6_col9, #T_e19f7_row12_col7, #T_e19f7_row14_col5 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col5 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col6, #T_e19f7_row6_col15, #T_e19f7_row6_col16, #T_e19f7_row8_col13 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col7, #T_e19f7_row14_col7 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_e19f7_row2_col8, #T_e19f7_row10_col8 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_e19f7_row2_col9, #T_e19f7_row14_col1, #T_e19f7_row15_col1 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col11 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_e19f7_row2_col12, #T_e19f7_row15_col4 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_e19f7_row2_col14, #T_e19f7_row7_col13 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col15 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_e19f7_row2_col16 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col17 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_e19f7_row2_col18, #T_e19f7_row8_col9 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col19, #T_e19f7_row20_col1 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_e19f7_row2_col22, #T_e19f7_row3_col21, #T_e19f7_row3_col22, #T_e19f7_row4_col20, #T_e19f7_row4_col21, #T_e19f7_row4_col22, #T_e19f7_row5_col19, #T_e19f7_row5_col20, #T_e19f7_row5_col21, #T_e19f7_row5_col22, #T_e19f7_row6_col18, #T_e19f7_row6_col19, #T_e19f7_row6_col20, #T_e19f7_row6_col21, #T_e19f7_row6_col22, #T_e19f7_row7_col17, #T_e19f7_row7_col18, #T_e19f7_row7_col19, #T_e19f7_row7_col20, #T_e19f7_row7_col21, #T_e19f7_row7_col22, #T_e19f7_row8_col16, #T_e19f7_row8_col17, #T_e19f7_row8_col18, #T_e19f7_row8_col19, #T_e19f7_row8_col20, #T_e19f7_row8_col21, #T_e19f7_row8_col22, #T_e19f7_row9_col15, #T_e19f7_row9_col16, #T_e19f7_row9_col17, #T_e19f7_row9_col18, #T_e19f7_row9_col19, #T_e19f7_row9_col20, #T_e19f7_row9_col21, #T_e19f7_row9_col22, #T_e19f7_row10_col14, #T_e19f7_row10_col15, #T_e19f7_row10_col16, #T_e19f7_row10_col17, #T_e19f7_row10_col18, #T_e19f7_row10_col19, #T_e19f7_row10_col20, #T_e19f7_row10_col21, #T_e19f7_row10_col22, #T_e19f7_row11_col13, #T_e19f7_row11_col14, #T_e19f7_row11_col15, #T_e19f7_row11_col16, #T_e19f7_row11_col17, #T_e19f7_row11_col18, #T_e19f7_row11_col19, #T_e19f7_row11_col20, #T_e19f7_row11_col21, #T_e19f7_row11_col22, #T_e19f7_row12_col12, #T_e19f7_row12_col13, #T_e19f7_row12_col14, #T_e19f7_row12_col15, #T_e19f7_row12_col16, #T_e19f7_row12_col17, #T_e19f7_row12_col18, #T_e19f7_row12_col19, #T_e19f7_row12_col20, #T_e19f7_row12_col21, #T_e19f7_row12_col22, #T_e19f7_row13_col11, #T_e19f7_row13_col12, #T_e19f7_row13_col13, #T_e19f7_row13_col14, #T_e19f7_row13_col15, #T_e19f7_row13_col16, #T_e19f7_row13_col17, #T_e19f7_row13_col18, #T_e19f7_row13_col19, #T_e19f7_row13_col20, #T_e19f7_row13_col21, #T_e19f7_row13_col22, #T_e19f7_row14_col10, #T_e19f7_row14_col11, #T_e19f7_row14_col12, #T_e19f7_row14_col13, #T_e19f7_row14_col14, #T_e19f7_row14_col15, #T_e19f7_row14_col16, #T_e19f7_row14_col17, #T_e19f7_row14_col18, #T_e19f7_row14

# %% [markdown]
# ### 2 Напишем функцию для подсчета retention

# %%
def retantion(date_start, date_end, details):
    # функция для подсчета retantion 
    '''
    На вход в функцию подаются данные:

    date_start - дата начала анализируемого периода
    date_end - дата окончания анализируемого периода + 1 день
    details - детализация анализа:
        - 'day' - день
        - 'mounth' - месяц
        - 'year' - год
    '''
    
    # проверка правильности задания переменной details
    if details == 'day':
        details_2 = "%Y-%m-%d"
    elif details == 'mounth':
        details_2 = "%Y-%m"
    elif details == 'year':
        details_2 = "%Y"
    else:
        print('Переменная details задана неверно')
        return
    
    # импортируем нужные библиотеки
    import pandas as pd
    import datetime as dt
    
    # проверка правильности указания дат
    if dt.datetime.strptime(date_start, "%Y-%m-%d").timestamp() > dt.datetime.strptime(date_end, "%Y-%m-%d").timestamp():
        print('Даты перепутаны местами')
        return
    
    # считывание файлов
    reg_data = pd.read_csv('shared/problem1-reg_data.csv', sep=';') 
    auth_data = pd.read_csv('shared/problem1-auth_data.csv', sep=';') 
    
    # проверка правильности указания дат
    if date_start < dt.datetime.utcfromtimestamp(reg_data.reg_ts.min()).strftime('%Y-%m-%d'):
        print('Переменная date_start задана неверно. Дата первой регистрации: 1998-11-18')
        return
    if date_start > (dt.datetime.utcfromtimestamp(reg_data.reg_ts.max()) + dt.timedelta(days=1)).strftime('%Y-%m-%d'):
        print('Переменная date_start задана неверно. Дата последней регистрации: 2020-09-23')
        return
    if date_end < dt.datetime.utcfromtimestamp(auth_data.auth_ts.max()).strftime('%Y-%m-%d'):
        print('Переменная date_end задана неверно. Дата первого захода пользователя в игру: 1998-11-18')
        return
    if date_end > (dt.datetime.utcfromtimestamp(auth_data.auth_ts.max()) + dt.timedelta(days=1)).strftime('%Y-%m-%d'):
        print('Переменная date_end задана неверно. Дата последнего захода пользователя в игру: 2020-09-23')
        return
    
    # переведем даты в формат timestamp
    date_start = dt.datetime.strptime(date_start, "%Y-%m-%d").timestamp()
    date_end = dt.datetime.strptime(date_end, "%Y-%m-%d").timestamp()
    
    # ограничиваем анализируемый период
    reg_data = reg_data.query('reg_ts >= @date_start')
    auth_data = auth_data.query('auth_ts >= @date_start')
    
    # объединяем таблицы
    cohort = reg_data.merge(auth_data, how='left', on='uid')
    
    # ограничиваем анализируемый период
    cohort = cohort.query('auth_ts <= @date_end')
    
    # меняем тип даты из timestamp в date
    cohort.reg_ts = cohort.reg_ts.apply(lambda x: dt.datetime.utcfromtimestamp(x).strftime(details_2))
    cohort.auth_ts = cohort.auth_ts.apply(lambda x: dt.datetime.utcfromtimestamp(x).strftime(details_2))
    
    # считаем количество уникальных пользователей
    cohort = cohort.groupby(['reg_ts', 'auth_ts'], as_index=False).agg({'uid': 'nunique'}) 
    
    # добавляем столбец с периодом
    cohort['period'] = cohort.sort_values(['reg_ts', 'auth_ts'], ascending=True).groupby(['reg_ts']).cumcount()
    
    # добавляем в таблицу столбец retention
    cohort['retention'] = cohort.uid / cohort.groupby('reg_ts')['uid'].transform('max') 
    
    # приводим в читаемый вид
    retention = cohort.pivot(index='reg_ts', columns='period', values='retention')
    
    # визуализируем
    ur_style = (retention
            .style
            .set_caption(f"User retention by cohort in {details}")  # добавляем подпись
            .background_gradient(cmap='viridis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{:.2%}", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту
    return ur_style

# %%
# Проверим расчет retention в днях 
retantion('2020-09-01', '2020-09-24', 'day')
# Out:
# <style  type="text/css" >
# #T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col7,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col22,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row2_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row2_col21,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col20,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row4_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row4_col19,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col18,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row6_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row6_col17,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col16,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row8_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row8_col15,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row9_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row9_col14,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row10_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row10_col13,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row11_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row11_col12,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row12_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row12_col11,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row13_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row13_col10,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row14_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row14_col9,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row15_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row15_col8,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row16_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row17_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row17_col6,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row18_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row18_col5,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row19_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row19_col4,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row20_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row20_col3,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row21_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row21_col2,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row22_col0,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row22_col1,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row23_col0{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col1,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col3,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col4,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col6,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col9,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col10,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col14,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col16,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col22,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col17,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col21,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row2_col20,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col2,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col13,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col15,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col19,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row4_col18,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row6_col8,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col11,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row8_col5,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row8_col12,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row10_col7{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col2{
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col5,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col4,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col6{
#             background-color:  #f8e621;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col8,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col9{
#             background-color:  #cde11d;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col11,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row11_col9{
#             background-color:  #228b8d;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col12,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row10_col1{
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col13,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row12_col9,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row15_col6{
#             background-color:  #25ab82;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col15{
#             background-color:  #2fb47c;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col17,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col12,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col15,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row2_col10,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col7,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row10_col10{
#             background-color:  #22a785;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col18,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col1{
#             background-color:  #25858e;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col19,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col16,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col8{
#             background-color:  #218f8d;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col20,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col4,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row11_col5{
#             background-color:  #20928c;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row0_col21,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row7_col2,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row11_col10,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row16_col2{
#             background-color:  #1f958b;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col1{
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col2{
#             background-color:  #24868e;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col3,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row11_col8{
#             background-color:  #20a386;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col4{
#             background-color:  #2e6f8e;
#             color:  #f1f1f1;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col5,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col9,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col10,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row6_col4{
#             background-color:  #42be71;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col6,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row2_col13{
#             background-color:  #33638d;
#             color:  #f1f1f1;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col7,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row4_col8{
#             background-color:  #a0da39;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col8,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row5_col12,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row8_col3{
#             background-color:  #228d8d;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col9,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row4_col5,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row15_col7{
#             background-color:  #3fbc73;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col10{
#             background-color:  #26818e;
#             color:  #000000;
#         }#T_3be53a10_9992_11ee_bdbb_96000040dfb6row1_col11,#T_3be53a10_9992_11ee_bdbb_96000040dfb6row3_col8,#T_3be53a10_9992_

# %%
# Проверим расчет retention в месяцах
retantion('2020-01-01', '2020-09-24', 'mounth')
# Out:
# <style  type="text/css" >
# #T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col1,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col3,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col2,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col0,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col0{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col1,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col2,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col3,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col8{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col2{
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col3{
#             background-color:  #481467;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col7{
#             background-color:  #471365;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row1_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col9,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col9{
#             background-color:  #440154;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col1,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col2{
#             background-color:  #481d6f;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col2,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col3{
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row2_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col3,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col2,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col3,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col8,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col1,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col2,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col3,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col7,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row9_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col1{
#             background-color:  #471164;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col3,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col4{
#             background-color:  #482979;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col5,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row3_col6,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col3{
#             background-color:  #482878;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col1,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col4,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col5{
#             background-color:  #482677;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row4_col2,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col1,#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row7_col1{
#             background-color:  #481668;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col1{
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col2{
#             background-color:  #46307e;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row5_col3{
#             background-color:  #472a7a;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row6_col2{
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }#T_dd30586c_8d50_11ee_bdbb_96000040dfb6row8_col1{
#             background-color:  #481769;
#             color:  #f1f1f1;
#         }</style><table id="T_dd30586c_8d50_11ee_bdbb_96000040dfb6" ><caption>User retention by cohort in mounth</caption><thead>    <tr>        <th class="index_name level0" >period</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>    </tr>    <tr>        <th class="index_name level0" >reg_ts</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd30586c_8d50_11ee_bdbb_96000040dfb6level0_row0" class="row_heading level0 row0" >2019-12</th>
#                         <td id="T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_dd30586c_8d50_11ee_bdbb_96000040dfb6row0_col1" class="data row0 col1" >25.56%</td>

# %%
# Проверим расчет retention в годах
retantion('2015-01-01', '2020-09-24', 'year')
# Out:
# <style  type="text/css" >
# #T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col0,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col0,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col1,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col2,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col3,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col4,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col5,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col0,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col0,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col0,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row5_col0,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row6_col0{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col1,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col2,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col3,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col4,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col4,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col3,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col4,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row5_col2,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row5_col3,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row5_col4,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row6_col1,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row6_col2,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row6_col3,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row6_col4{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col5,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col5,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col5,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col5,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row5_col5,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row6_col5{
#             background-color:  #440154;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col1{
#             background-color:  #4cc26c;
#             color:  #000000;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col2,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col3{
#             background-color:  #a0da39;
#             color:  #000000;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col4,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col1,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col2,#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col3{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col1{
#             background-color:  #67cc5c;
#             color:  #000000;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col2{
#             background-color:  #a2da37;
#             color:  #000000;
#         }#T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row5_col1{
#             background-color:  #90d743;
#             color:  #000000;
#         }</style><table id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6" ><caption>User retention by cohort in year</caption><thead>    <tr>        <th class="index_name level0" >period</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>    </tr>    <tr>        <th class="index_name level0" >reg_ts</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6level0_row0" class="row_heading level0 row0" >2014</th>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col1" class="data row0 col1" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col2" class="data row0 col2" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col3" class="data row0 col3" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col4" class="data row0 col4" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row0_col5" class="data row0 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6level0_row1" class="row_heading level0 row1" >2015</th>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col0" class="data row1 col0" >100.00%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col1" class="data row1 col1" >6.34%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col2" class="data row1 col2" >4.90%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col3" class="data row1 col3" >4.90%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col4" class="data row1 col4" >4.90%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row1_col5" class="data row1 col5" >4.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6level0_row2" class="row_heading level0 row2" >2016</th>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col0" class="data row2 col0" >100.00%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col1" class="data row2 col1" >6.49%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col2" class="data row2 col2" >5.01%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col3" class="data row2 col3" >5.01%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col4" class="data row2 col4" >5.01%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row2_col5" class="data row2 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6level0_row3" class="row_heading level0 row3" >2017</th>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col0" class="data row3 col0" >100.00%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col1" class="data row3 col1" >6.55%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col2" class="data row3 col2" >5.03%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col3" class="data row3 col3" >5.03%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col4" class="data row3 col4" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row3_col5" class="data row3 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6level0_row4" class="row_heading level0 row4" >2018</th>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col1" class="data row4 col1" >6.50%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col2" class="data row4 col2" >5.01%</td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col3" class="data row4 col3" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col4" class="data row4 col4" ></td>
#                         <td id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6row4_col5" class="data row4 col5" ></td>
#             </tr>
#             <tr>
#                         <th id="T_36eac0c2_8d51_11ee_bdbb_96000040dfb6level0_row5" class="row_heading

# %%
# Проверим расчет retention, если неверно указана детализация
retantion('2020-09-01', '2020-09-24', 'ошибка')
# Out:
# Переменная details задана неверно

# %%
# Проверим расчет retention, если даты перепутаны местами
retantion('2020-09-24', '2020-09-01', 'day')
# Out:
# Даты перепутаны местами

# %%
# Проверим расчет retention, если указать неверно первую дату
retantion('1997-01-01', '2020-09-01', 'year')
# Out:
# Переменная date_start задана неверно. Дата первой регистрации: 1998-11-18

# %%
# Проверим расчет retention, если указать неверно вторую дату
retantion('2000-01-01', '2022-09-01', 'year')
# Out:
# Переменная date_end задана неверно. Дата последнего захода пользователя в игру: 2020-09-23
